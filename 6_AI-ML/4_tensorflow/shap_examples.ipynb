# %% [markdown]
# Run with a Python runtime and at least one GPU.

# %%
# this is the code from https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 100

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/100
# 469/469 [==============================] - 15s 13ms/step - loss: 2.2706 - accuracy: 0.1503 - val_loss: 2.2187 - val_accuracy: 0.3564
# Epoch 2/100
# 469/469 [==============================] - 4s 9ms/step - loss: 2.1864 - accuracy: 0.2776 - val_loss: 2.1146 - val_accuracy: 0.5715
# Epoch 3/100
# 469/469 [==============================] - 4s 9ms/step - loss: 2.0800 - accuracy: 0.3855 - val_loss: 1.9771 - val_accuracy: 0.6835
# Epoch 4/100
# 469/469 [==============================] - 5s 10ms/step - loss: 1.9396 - accuracy: 0.4726 - val_loss: 1.7979 - val_accuracy: 0.7332
# Epoch 5/100
# 469/469 [==============================] - 4s 9ms/step - loss: 1.7645 - accuracy: 0.5433 - val_loss: 1.5839 - val_accuracy: 0.7624
# Epoch 6/100
# 469/469 [==============================] - 5s 10ms/step - loss: 1.5770 - accuracy: 0.5938 - val_loss: 1.3618 - val_accuracy: 0.7855
# Epoch 7/100
# 469/469 [==============================] - 4s 9ms/step - loss: 1.4004 - accuracy: 0.6295 - val_loss: 1.1619 - val_accuracy: 0.8034
# Epoch 8/100
# 469/469 [==============================] - 4s 9ms/step - loss: 1.2477 - accuracy: 0.6601 - val_loss: 0.9996 - val_accuracy: 0.8152
# Epoch 9/100
# 469/469 [==============================] - 5s 10ms/step - loss: 1.1260 - accuracy: 0.6834 - val_loss: 0.8738 - val_accuracy: 0.8268
# Epoch 10/100
# 469/469 [==============================] - 4s 9ms/step - loss: 1.0321 - accuracy: 0.7025 - val_loss: 0.7789 - val_accuracy: 0.8378
# Epoch 11/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.9550 - accuracy: 0.7216 - val_loss: 0.7060 - val_accuracy: 0.8454
# Epoch 12/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.8914 - accuracy: 0.7352 - val_loss: 0.6489 - val_accuracy: 0.8510
# Epoch 13/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.8461 - accuracy: 0.7457 - val_loss: 0.6040 - val_accuracy: 0.8570
# Epoch 14/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.8000 - accuracy: 0.7609 - val_loss: 0.5675 - val_accuracy: 0.8606
# Epoch 15/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.7653 - accuracy: 0.7687 - val_loss: 0.5382 - val_accuracy: 0.8654
# Epoch 16/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.7346 - accuracy: 0.7783 - val_loss: 0.5131 - val_accuracy: 0.8715
# Epoch 17/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.7108 - accuracy: 0.7840 - val_loss: 0.4921 - val_accuracy: 0.8747
# Epoch 18/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.6865 - accuracy: 0.7896 - val_loss: 0.4739 - val_accuracy: 0.8779
# Epoch 19/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.6671 - accuracy: 0.7977 - val_loss: 0.4575 - val_accuracy: 0.8801
# Epoch 20/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.6500 - accuracy: 0.8014 - val_loss: 0.4436 - val_accuracy: 0.8830
# Epoch 21/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.6377 - accuracy: 0.8048 - val_loss: 0.4311 - val_accuracy: 0.8861
# Epoch 22/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.6173 - accuracy: 0.8123 - val_loss: 0.4198 - val_accuracy: 0.8887
# Epoch 23/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.6061 - accuracy: 0.8150 - val_loss: 0.4101 - val_accuracy: 0.8899
# Epoch 24/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5921 - accuracy: 0.8193 - val_loss: 0.4007 - val_accuracy: 0.8912
# Epoch 25/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.5857 - accuracy: 0.8231 - val_loss: 0.3923 - val_accuracy: 0.8929
# Epoch 26/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5721 - accuracy: 0.8241 - val_loss: 0.3843 - val_accuracy: 0.8955
# Epoch 27/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5634 - accuracy: 0.8282 - val_loss: 0.3771 - val_accuracy: 0.8965
# Epoch 28/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.5516 - accuracy: 0.8312 - val_loss: 0.3697 - val_accuracy: 0.8983
# Epoch 29/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5434 - accuracy: 0.8340 - val_loss: 0.3636 - val_accuracy: 0.8997
# Epoch 30/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5393 - accuracy: 0.8369 - val_loss: 0.3577 - val_accuracy: 0.9005
# Epoch 31/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.5292 - accuracy: 0.8396 - val_loss: 0.3522 - val_accuracy: 0.9017
# Epoch 32/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5270 - accuracy: 0.8412 - val_loss: 0.3469 - val_accuracy: 0.9031
# Epoch 33/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5133 - accuracy: 0.8450 - val_loss: 0.3417 - val_accuracy: 0.9049
# Epoch 34/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.5086 - accuracy: 0.8460 - val_loss: 0.3369 - val_accuracy: 0.9067
# Epoch 35/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5040 - accuracy: 0.8467 - val_loss: 0.3323 - val_accuracy: 0.9082
# Epoch 36/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4961 - accuracy: 0.8506 - val_loss: 0.3282 - val_accuracy: 0.9088
# Epoch 37/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4905 - accuracy: 0.8510 - val_loss: 0.3241 - val_accuracy: 0.9101
# Epoch 38/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4869 - accuracy: 0.8525 - val_loss: 0.3201 - val_accuracy: 0.9109
# Epoch 39/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4818 - accuracy: 0.8540 - val_loss: 0.3166 - val_accuracy: 0.9118
# Epoch 40/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4753 - accuracy: 0.8573 - val_loss: 0.3125 - val_accuracy: 0.9121
# Epoch 41/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4672 - accuracy: 0.8573 - val_loss: 0.3087 - val_accuracy: 0.9126
# Epoch 42/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4676 - accuracy: 0.8587 - val_loss: 0.3054 - val_accuracy: 0.9133
# Epoch 43/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4591 - accuracy: 0.8612 - val_loss: 0.3020 - val_accuracy: 0.9138
# Epoch 44/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.4593 - accuracy: 0.8626 - val_loss: 0.2987 - val_accuracy: 0.9152
# Epoch 45/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4565 - accuracy: 0.8627 - val_loss: 0.2955 - val_accuracy: 0.9158
# Epoch 46/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4460 - accuracy: 0.8653 - val_loss: 0.2928 - val_accuracy: 0.9165
# Epoch 47/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4443 - accuracy: 0.8658 - val_loss: 0.2899 - val_accuracy: 0.9169
# Epoch 48/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4436 - accuracy: 0.8663 - val_loss: 0.2872 - val_accuracy: 0.9180
# Epoch 49/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4365 - accuracy: 0.8681 - val_loss: 0.2841 - val_accuracy: 0.9184
# Epoch 50/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.4342 - accuracy: 0.8688 - val_loss: 0.2812 - val_accuracy: 0.9198
# Epoch 51/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4323 - accuracy: 0.8702 - val_loss: 0.2787 - val_accuracy: 0.9208
# Epoch 52/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4248 - accuracy: 0.8727 - val_loss: 0.2759 - val_accuracy: 0.9213
# Epoch 53/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4229 - accuracy: 0.8719 - val_loss: 0.2737 - val_accuracy: 0.9224
# Epoch 54/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4194 - accuracy: 0.8743 - val_loss: 0.2714 - val_accuracy: 0.9230
# Epoch 55/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4184 - accuracy: 0.8747 - val_loss: 0.2691 - val_accuracy: 0.9241
# Epoch 56/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4172 - accuracy: 0.8746 - val_loss: 0.2673 - val_accuracy: 0.9241
# Epoch 57/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4116 - accuracy: 0.8781 - val_loss: 0.2648 - val_accuracy: 0.9247
# Epoch 58/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.4132 - accuracy: 0.8756 - val_loss: 0.2629 - val_accuracy: 0.9250
# Epoch 59/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4032 - accuracy: 0.8789 - val_loss: 0.2604 - val_accuracy: 0.9262
# Epoch 60/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4048 - accuracy: 0.8782 - val_loss: 0.2583 - val_accuracy: 0.9265
# Epoch 61/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.4027 - accuracy: 0.8773 - val_loss: 0.2564 - val_accuracy: 0.9277
# Epoch 62/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3991 - accuracy: 0.8800 - val_loss: 0.2546 - val_accuracy: 0.9277
# Epoch 63/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3956 - accuracy: 0.8822 - val_loss: 0.2525 - val_accuracy: 0.9282
# Epoch 64/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.3914 - accuracy: 0.8826 - val_loss: 0.2506 - val_accuracy: 0.9282
# Epoch 65/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3889 - accuracy: 0.8825 - val_loss: 0.2486 - val_accuracy: 0.9285
# Epoch 66/100
# 469/469 [==============================] - 4s 10ms/step - loss: 0.3898 - accuracy: 0.8831 - val_loss: 0.2468 - val_accuracy: 0.9292
# Epoch 67/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3858 - accuracy: 0.8834 - val_loss: 0.2456 - val_accuracy: 0.9297
# Epoch 68/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3830 - accuracy: 0.8860 - val_loss: 0.2436 - val_accuracy: 0.9304
# Epoch 69/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3814 - accuracy: 0.8867 - val_loss: 0.2419 - val_accuracy: 0.9313
# Epoch 70/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3785 - accuracy: 0.8861 - val_loss: 0.2404 - val_accuracy: 0.9311
# Epoch 71/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3746 - accuracy: 0.8887 - val_loss: 0.2386 - val_accuracy: 0.9318
# Epoch 72/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3733 - accuracy: 0.8881 - val_loss: 0.2370 - val_accuracy: 0.9322
# Epoch 73/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3736 - accuracy: 0.8886 - val_loss: 0.2354 - val_accuracy: 0.9324
# Epoch 74/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3698 - accuracy: 0.8885 - val_loss: 0.2340 - val_accuracy: 0.9332
# Epoch 75/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3696 - accuracy: 0.8893 - val_loss: 0.2329 - val_accuracy: 0.9335
# Epoch 76/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3700 - accuracy: 0.8886 - val_loss: 0.2311 - val_accuracy: 0.9337
# Epoch 77/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3636 - accuracy: 0.8898 - val_loss: 0.2295 - val_accuracy: 0.9348
# Epoch 78/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3617 - accuracy: 0.8912 - val_loss: 0.2280 - val_accuracy: 0.9345
# Epoch 79/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3610 - accuracy: 0.8921 - val_loss: 0.2266 - val_accuracy: 0.9349
# Epoch 80/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3588 - accuracy: 0.8934 - val_loss: 0.2254 - val_accuracy: 0.9354
# Epoch 81/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3573 - accuracy: 0.8930 - val_loss: 0.2239 - val_accuracy: 0.9353
# Epoch 82/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3554 - accuracy: 0.8918 - val_loss: 0.2227 - val_accuracy: 0.9362
# Epoch 83/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3531 - accuracy: 0.8940 - val_loss: 0.2214 - val_accuracy: 0.9365
# Epoch 84/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3531 - accuracy: 0.8934 - val_loss: 0.2202 - val_accuracy: 0.9368
# Epoch 85/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3539 - accuracy: 0.8939 - val_loss: 0.2189 - val_accuracy: 0.9374
# Epoch 86/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3475 - accuracy: 0.8968 - val_loss: 0.2176 - val_accuracy: 0.9376
# Epoch 87/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3483 - accuracy: 0.8956 - val_loss: 0.2167 - val_accuracy: 0.9377
# Epoch 88/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3446 - accuracy: 0.8987 - val_loss: 0.2151 - val_accuracy: 0.9382
# Epoch 89/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3442 - accuracy: 0.8964 - val_loss: 0.2140 - val_accuracy: 0.9390
# Epoch 90/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3391 - accuracy: 0.9004 - val_loss: 0.2127 - val_accuracy: 0.9388
# Epoch 91/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3409 - accuracy: 0.8985 - val_loss: 0.2116 - val_accuracy: 0.9393
# Epoch 92/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3366 - accuracy: 0.9000 - val_loss: 0.2102 - val_accuracy: 0.9397
# Epoch 93/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3376 - accuracy: 0.9008 - val_loss: 0.2091 - val_accuracy: 0.9400
# Epoch 94/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3377 - accuracy: 0.8997 - val_loss: 0.2080 - val_accuracy: 0.9405
# Epoch 95/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3344 - accuracy: 0.9013 - val_loss: 0.2070 - val_accuracy: 0.9410
# Epoch 96/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3314 - accuracy: 0.9026 - val_loss: 0.2059 - val_accuracy: 0.9414
# Epoch 97/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3329 - accuracy: 0.9020 - val_loss: 0.2047 - val_accuracy: 0.9418
# Epoch 98/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3334 - accuracy: 0.9002 - val_loss: 0.2039 - val_accuracy: 0.9419
# Epoch 99/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3286 - accuracy: 0.9015 - val_loss: 0.2027 - val_accuracy: 0.9421
# Epoch 100/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3288 - accuracy: 0.9015 - val_loss: 0.2018 - val_accuracy: 0.9420
# Test loss: 0.2018442004919052
# Test accuracy: 0.9419999718666077

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.45.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (538 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.2)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.45.0 slicer-0.0.7

# %%
# ...include code from https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py

import shap
import numpy as np

# select a set of background examples to take an expectation over
background = x_train[np.random.choice(x_train.shape[0], 100, replace=False)]

# explain predictions of the model on three images
# e = shap.DeepExplainer(model, background)
# ...or pass tensors directly
e = shap.DeepExplainer((model.layers[0].input, model.layers[-1].output), background)
shap_values = e.shap_values(x_test[1:5])
# Out:
# /usr/local/lib/python3.10/dist-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(

# %%
print(x_test.shape)
# plot the feature attributions
shap.image_plot(shap_values, -x_test[1:5])
# Out:
# (10000, 28, 28, 1)

# %% [markdown]
# The plot above shows the explanations for each class on four predictions. Note that the explanations are ordered for the classes 0-9 going left to right along the rows.

# %%
import transformers
import shap

# load a transformers pipeline model
model = transformers.pipeline('sentiment-analysis', return_all_scores=True)

# explain the model on two sample inputs
explainer = shap.Explainer(model)
shap_values = explainer(["What a great movie! ...if you have no taste....What a bad movie! ...but I loved it."])

# visualize the first prediction's explanation for the POSITIVE & NEGATIVE output classes
shap.plots.text(shap_values[0, :, "POSITIVE"])
shap.plots.text(shap_values[0, :, "NEGATIVE"])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:33, 33.31s/it]
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="52.417450464567096%" y1="33" x2="52.417450464567096%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="52.417450464567096%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="37.597073817309%" y1="33" x2="37.597073817309%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.597073817309%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="22.776697170050898%" y1="33" x2="22.776697170050898%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.776697170050898%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="7.95632052279279%" y1="33" x2="7.95632052279279%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="7.95632052279279%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="67.2378271118252%" y1="33" x2="67.2378271118252%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="67.2378271118252%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="82.05820375908331%" y1="33" x2="82.05820375908331%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.05820375908331%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.2</text><line x1="32.7831299411044%" y1="33" x2="32.7831299411044%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.7831299411044%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.535036</text><text x="32.7831299411044%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.535036</text><text x="32.7831299411044%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="67.21686931787677%" y1="33" x2="67.21686931787677%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="67.21686931787677%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999717</text><text x="67.21686931787677%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.999717</text><text x="67.21686931787677%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">POSITIVE</tspan>(inputs)</text><rect x="8.425179063184823%" width="58.79169025469195%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="38.11181118502307%" x2="67.21686931787677%" y1="60" y2="60" id="_fb_bqqcnelgbwmegcohadtx_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="52.66434025144992%" y="71" font-size="12px" id="_fs_bqqcnelgbwmegcohadtx_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.393</text><svg x="38.11181118502307%" y="40" height="20" width="29.1050581328537%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">great</text>  </svg></svg><line x1="21.284404727892834%" x2="38.11181118502307%" y1="60" y2="60" id="_fb_bqqcnelgbwmegcohadtx_ind_28" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="29.698107956457953%" y="71" font-size="12px" id="_fs_bqqcnelgbwmegcohadtx_ind_28" fill="rgb(255.0, 0.0, 81. ...
# <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.58255125434716%" y1="33" x2="47.58255125434716%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.58255125434716%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="32.7621752764635%" y1="33" x2="32.7621752764635%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.7621752764635%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="17.94179929857984%" y1="33" x2="17.94179929857984%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.94179929857984%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.2</text><line x1="62.40292723223083%" y1="33" x2="62.40292723223083%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="62.40292723223083%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="77.2233032101145%" y1="33" x2="77.2233032101145%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.2233032101145%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="92.04367918799815%" y1="33" x2="92.04367918799815%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="92.04367918799815%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="67.21686868260159%" y1="33" x2="67.21686868260159%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="67.21686868260159%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.464964</text><text x="67.21686868260159%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.464964</text><text x="67.21686868260159%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="32.78313057637963%" y1="33" x2="32.78313057637963%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.78313057637963%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00028279</text><text x="32.78313057637963%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.00028279</text><text x="32.78313057637963%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">NEGATIVE</tspan>(inputs)</text><rect x="8.425179532148677%" width="24.35795104423095%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="26.136158566997242%" x2="32.78313057637963%" y1="60" y2="60" id="_fb_sbvqqpjqoenxgpadfjfl_ind_20" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="29.459644571688436%" y="71" font-size="12px" id="_fs_sbvqqpjqoenxgpadfjfl_ind_20" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.09</text><svg x="26.136158566997242%" y="40" height="20" width="6.6469720093823845%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">bad</text>  </svg></svg><line x1="22.991075064332154%" x2="26.136158566997242%" y1="60" y2="60" id="_fb_sbvqqpjqoenxgpadfjfl_ind_22" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="24.563616815664698%" y="71" font-size="12px" id="_fs_sbvqqpjqoenxgpadfjfl_ind_22" fill="rgb( ...
